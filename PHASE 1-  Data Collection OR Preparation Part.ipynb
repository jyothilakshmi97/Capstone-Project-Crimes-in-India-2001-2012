# %%
#Import basic libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
df = pd.read_csv("Final_Dataset__of_India_Crimes.csv")
df
# Out:
#               STATE/UT  YEAR  POPULATION  MURDER  ATTEMPT TO MURDER  \
# 0       ANDHRA PRADESH  2001    76210007    2602               1555
# 1    ARUNACHAL PRADESH  2001     1097968      83                 53
# 2                ASSAM  2001    26655528    1356                481
# 3                BIHAR  2001    82998509    3643               3419
# 4         CHHATTISGARH  2001    20733232     880                529
# ..                 ...   ...         ...     ...                ...
# 403         CHANDIGARH  2012     1144839      21                 44
# 404       D & N HAVELI  2012      259148       7                  2
# 405        DAMAN & DIU  2012      191924       3                  5
# 406        LAKSHADWEEP  2012       74578       0                  0
# 407         PUDUCHERRY  2012     1148900      29                 27
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                          136   871               0
# ...
